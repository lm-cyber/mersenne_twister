# %%
import numpy as np
import matplotlib.pyplot as plt
plt.rcParams['figure.figsize'] = [16,10]
plt.rcParams.update({'font.size':18})
f = open('data.txt', 'r')
step =0.0001
kol = np.arange(start=0,stop=1,step=step)
mass_of_date = [float(el) for el in f.read().split()]
plt.plot(kol,mass_of_date,color='green',linewidth=0.2,label='data')
plt.legend()

# %%
from scipy.fft import rfft,rfftfreq
n    = len(kol)
yf   = rfft(mass_of_date)
xf   = rfftfreq(n,step)
plt.plot(xf,np.abs(yf))

# %%
f1 = open('data1.txt', 'r')
step =0.001
kol = np.arange(start=0,stop=1,step=step)
mass_of_date1 = [float(el) for el in f1.read().split()]
plt.plot(kol,mass_of_date1,color='green',linewidth=1.5,label='data')
plt.legend()

# %%
n    = len(kol)
yf   = rfft(mass_of_date1)
xf   = rfftfreq(n,step)
plt.plot(xf,np.abs(yf))

# %%
from scipy.fft import irfft
yf_abs      = np.abs(yf) 
indices     = yf_abs>200
yf_clean    = indices * yf 
new_f_clean = irfft(yf_clean)
plt.plot(kol,new_f_clean)
plt.legend()
# Out:
# No artists with labels found to put in legend.  Note that artists whose label start with an underscore are ignored when legend() is called with no argument.
